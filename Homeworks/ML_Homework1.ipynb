# %% [markdown]
# # **Homework One**

# %% [markdown]
# 1. How would you define Machine Learning?
# 2. What are the differences between Supervised and Unsupervised Learning? Specify example 3 algorithms for each of these.
# 3. What are the test and validation set, and why would you want to use them?
# 4. What are the main preprocessing steps? Explain them in detail. Why we need to prepare our data?
# 5. How you can explore and analyse countionus and discrete variables?
# 6. Analyse the plot given below. (What is the plot and variable type, check the distribution and make comment about how you can preproccess it.)

# %% [markdown]
# #### *How would you define Machine Learning?*
# > Machine Learning is the process of computers to learn without directly being typed, instead the programmer gives input and output data into the required function and then creates models. These models has the ability to predict.

# %% [markdown]
# #### *What are the differences between Supervised and Unsupervised Learning? Specify example 3 algorithms for each of these.*
# > In the case of **Supervised Learning** we give the input and output data, then we expect the algorithm. On the other hand, in **Unsupervised Learning** we only provide the input data, and then computer tries to make predictions.
#
# > *Supervised:*
# 1. Linear Regression
# 2. Logical Regression
# 3. Ensemble Methods
#
# > *Unsupervised:*
# 1. Clustering
# 2. Association
# 3. K Means

# %% [markdown]
# #### *What are the test and validation set, and why would you want to use them?*
# >While we are trying to create a machine learning model we need to split our data.
#
# > This can done in two ways:
# - 2 parts => Train{70%} + Test{30%}
# - 3 parts => Train{60%} + Validation{20%} + Test{20%}
#
# > **Test** set is used to check our model accuracy, wheter it underfits or overfits?
#
# > **Validation** set is used to improve the model created by the Train set.

# %% [markdown]
# #### *What are the main preprocessing steps? Explain them in detail. Why we need to prepare our data?*
#
# 1. Removing duplicate values
# 2. Find imbalanced Data
# 3. Eliminate missing values by filling them with median or mean
# 4. Outlier Detection
# 5. Standardization and Normalization
# 6. Feature Encoding

# %% [markdown]
# #### *How you can explore and analyse countionus and discrete variables?*
#
# 1. **discrete** variable : They have finite value options they can take. In order to explore *discrete variables* we need to use Probability Mass Function.
# 2. **continuous** variable : They have infinte value options they can take. In order to explore them we use Probability Density Function.

# %% [markdown]
# #### *Analyse the plot given below. (What is the plot and variable type, check the distribution and make comment about how you can preproccess it.)*
#
# 1. As the first step we need to find out residual data which is most probablt bar {0.1}.
# 2. We need to fill empty spaces with mean or median.
# 3. We need to normalize and standardize the data

# %% [markdown]
# ![Ekran Resmi 2021-03-28 22.58.45.png](data:image/png;base64,...)
